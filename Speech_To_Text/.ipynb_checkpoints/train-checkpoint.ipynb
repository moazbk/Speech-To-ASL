# %%
from preprocess import *
import keras
from sklearn.externals import joblib
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.utils import to_categorical


feature_dim_2 = 11
# Transform each class into  array of MFCC vectors and save into a file
save_data_to_array(max_len=feature_dim_2)

# # Loading train set and test set
X_train, X_test, y_train, y_test = get_train_test()

# # Feature dimension
feature_dim_1 = 20

channel = 1
epochs = 50
batch_size = 80
verbose = 10
num_classes = 27

# Reshaping to perform 2D convolution
X_train = X_train.reshape(X_train.shape[0], feature_dim_1, feature_dim_2, channel)
X_test = X_test.reshape(X_test.shape[0], feature_dim_1, feature_dim_2, channel)


y_train_hot = to_categorical(y_train)
y_test_hot = to_categorical(y_test)

def get_model(feature_dim_1,feature_dim_2,channel):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(feature_dim_1, feature_dim_2, channel)))
    model.add(Conv2D(48, kernel_size=(3, 3), activation='relu'))
    model.add(Conv2D(120, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    return model
model = get_model(feature_dim_1,feature_dim_2,channel)
model.fit(X_train, y_train_hot, batch_size=batch_size, epochs=epochs, verbose=verbose, validation_data=(X_test, y_test_hot))
filename = 'finalized_model.sav'
joblib.dump(model, filename)
# Out:
# Using TensorFlow backend.
# C:\Users\EAGLE\Anaconda3\envs\g2\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# Saving vectors of label - 'a': 100%|██████████| 40/40 [00:00<00:00, 110.19it/s]
# Saving vectors of label - 'about': 100%|██████| 33/33 [00:00<00:00, 113.01it/s]
# Saving vectors of label - 'be': 100%|█████████| 36/36 [00:00<00:00, 114.25it/s]
# Saving vectors of label - 'break': 100%|██████| 13/13 [00:00<00:00, 102.36it/s]
# Saving vectors of label - 'complete': 100%|████| 13/13 [00:00<00:00, 97.74it/s]
# Saving vectors of label - 'e-learning': 100%|█| 30/30 [00:00<00:00, 107.14it/s]
# Saving vectors of label - 'from': 100%|███████| 39/39 [00:00<00:00, 114.03it/s]
# Saving vectors of label - 'have': 100%|███████| 12/12 [00:00<00:00, 105.26it/s]
# Saving vectors of label - 'how': 100%|████████| 15/15 [00:00<00:00, 104.16it/s]
# Saving vectors of label - 'internet': 100%|███| 52/52 [00:00<00:00, 103.99it/s]
# Saving vectors of label - 'is': 100%|██████████| 54/54 [00:00<00:00, 83.85it/s]
# Saving vectors of label - 'issues': 100%|█████| 31/31 [00:00<00:00, 107.26it/s]
# Saving vectors of label - 'lecture': 100%|█████| 45/45 [00:00<00:00, 96.77it/s]
# Saving vectors of label - 'major': 100%|██████| 38/38 [00:00<00:00, 111.76it/s]
# Saving vectors of label - 'no': 100%|█████████| 13/13 [00:00<00:00, 109.24it/s]
# Saving vectors of label - 'on': 100%|█████████| 39/39 [00:00<00:00, 116.06it/s]
# Saving vectors of label - 'Recognition': 100%|█| 44/44 [00:00<00:00, 108.64it/s]
# Saving vectors of label - 'security': 100%|███| 32/32 [00:00<00:00, 105.95it/s]
# Saving vectors of label - 'Speech': 100%|██████| 26/26 [00:00<00:00, 98.85it/s]
# Saving vectors of label - 'submission': 100%|█| 30/30 [00:00<00:00, 108.30it/s]
# Saving vectors of label - 'suffers': 100%|████| 33/33 [00:00<00:00, 104.07it/s]
# Saving vectors of label - 'the': 100%|████████| 44/44 [00:00<00:00, 113.98it/s]
# Saving vectors of label - 'there': 100%|██████| 46/46 [00:00<00:00, 112.18it/s]
# Saving vectors of label - 'to': 100%|██████████| 11/11 [00:00<00:00, 94.82it/s]
# Saving vectors of label - 'today': 100%|███████| 17/17 [00:00<00:00, 94.97it/s]
# Saving vectors of label - 'will': 100%|███████| 49/49 [00:00<00:00, 111.10it/s]
# Saving vectors of label - 'works': 100%|███████| 25/25 [00:00<00:00, 71.02it/s]
# ['a', 'about', 'be', 'break', 'complete', 'e-learning', 'from', 'have', 'how', 'internet', 'is', 'issues', 'lecture', 'major', 'no', 'on', 'Recognition', 'security', 'Speech', 'submission', 'suffers', 'the', 'there', 'to', 'today', 'will', 'works']
# WARNING:tensorflow:From C:\Users\EAGLE\Anaconda3\envs\g2\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\EAGLE\Anaconda3\envs\g2\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\EAGLE\Anaconda3\envs\g2\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 516 samples, validate on 344 samples
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# ['finalized_model.sav']
